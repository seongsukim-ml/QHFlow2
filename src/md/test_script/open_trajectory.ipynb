# %%
import ase
from ase.io import Trajectory

# %%
trj = Trajectory("/root/25DFT/QHFlow/src/outputs/rmd-salicylic_acid/QHFlow_so2_v5_1_middle-rmd-salicylic_acid/md_scflow_300ps_123/atoms.traj")

# %%
trj[0]
# Out:
# Atoms(symbols='C3OC4O2H6', pbc=True, cell=[1000.0, 1000.0, 1000.0], momenta=..., calculator=SinglePointCalculator(...))

# %%
trj[-1].positions
# Out:
# array([[ 1.32120279, -0.07420284,  0.17352364],
#        [-0.10603455, -0.36093004,  0.57791663],
#        [-0.72824519,  0.88101322,  0.37041699],
#        [-0.22010225,  1.90748204, -0.17374098],
#        [-2.08737854,  0.92864763, -0.354095  ],
#        [-2.90212886,  0.05583576,  0.36140022],
#        [-1.66658029, -1.50139824,  0.17998168],
#        [-0.17756836, -1.74148759,  0.39409761],
#        [ 2.00070698,  0.76157684,  0.35552782],
#        [ 1.95511845, -1.25670328, -0.0389556 ],
#        [ 0.22952418, -0.17994903, -1.52941836],
#        [-2.77182309,  2.26445088, -0.40176163],
#        [-3.44245728,  0.20069486, -0.76879656],
#        [-1.97841346, -2.68440061, -1.25793882],
#        [ 0.69769032, -2.87559019,  0.89571535],
#        [ 2.97460646,  1.07434063,  0.49835328]])

# %%
trj[-1].get_potential_energy()
# Out:
# -490.89095103590864

# %%
trj.__dir__()
# Out:
# ['numbers',
#  'pbc',
#  'masses',
#  'backend',
#  'constraints',
#  'description',
#  'version',
#  'ase_version',
#  '__module__',
#  '__doc__',
#  '__init__',
#  '__enter__',
#  '__exit__',
#  '_open',
#  '_read_header',
#  'close',
#  '__getitem__',
#  '__len__',
#  '__iter__',
#  '__dict__',
#  '__weakref__',
#  '__new__',
#  '__repr__',
#  '__hash__',
#  '__str__',
#  '__getattribute__',
#  '__setattr__',
#  '__delattr__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__reduce_ex__',
#  '__reduce__',
#  '__getstate__',
#  '__subclasshook__',
#  '__init_subclass__',
#  '__format__',
#  '__sizeof__',
#  '__dir__',
#  '__class__']

# %%
trj[-1].__dir__()
# Out:
# ['_cellobj',
#  '_pbc',
#  'arrays',
#  '_celldisp',
#  '_constraints',
#  'info',
#  '_calc',
#  '__module__',
#  '__doc__',
#  'ase_objtype',
#  '__init__',
#  'symbols',
#  'set_calculator',
#  'get_calculator',
#  'calc',
#  'number_of_lattice_vectors',
#  'set_constraint',
#  '_get_constraints',
#  '_del_constraints',
#  'constraints',
#  'set_cell',
#  'set_celldisp',
#  'get_celldisp',
#  'get_cell',
#  'get_cell_lengths_and_angles',
#  'get_reciprocal_cell',
#  'pbc',
#  'set_pbc',
#  'get_pbc',
#  'new_array',
#  'get_array',
#  'set_array',
#  'has',
#  'set_atomic_numbers',
#  'get_atomic_numbers',
#  'get_chemical_symbols',
#  'set_chemical_symbols',
#  'get_chemical_formula',
#  'set_tags',
#  'get_tags',
#  'set_momenta',
#  'set_velocities',
#  'get_momenta',
#  'set_masses',
#  'get_masses',
#  'set_initial_magnetic_moments',
#  'get_initial_magnetic_moments',
#  'get_magnetic_moments',
#  'get_magnetic_moment',
#  'set_initial_charges',
#  'get_initial_charges',
# ...
