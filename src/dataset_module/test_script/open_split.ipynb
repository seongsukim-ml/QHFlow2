# %%
import json
file_path = "/root/25DFT/QHFlow/dataset/QH9Stable_shard/processed/processed_QH9Stable_random_12.json"

# %%
split=json.load(open(file_path))
train = split['train']
val = split['val']
test = split['test']

# %%
test[10493]
# Out:
# 21602

# %%
train[128]
# Out:
# 177
